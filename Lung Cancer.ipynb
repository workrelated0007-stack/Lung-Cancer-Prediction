jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (535).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (530).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (473).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (471).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (540).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (508).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (519).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (510).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (468).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (503).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (491).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (523).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (501).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (494).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (489).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (461).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (514).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (492).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (496).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (465).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (482).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (518).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (497).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (507).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (516).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (478).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (467).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (484).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (525).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (472).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (512).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (506).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (534).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (101).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (108).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (111).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (104).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (102).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (109).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (105).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (106).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (107).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (110).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/BenginCases/Bengin case (103).jpg
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000142 (6).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000121.png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000166 (4).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000167 (2).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000148 (4).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000108 (6).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000136 (4).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000133 (2).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000154 (4).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000114 (3).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000148 (3).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000115 (5).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000139 (5).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000163 (4).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000127.png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000129 (2).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000156 (2).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000112.png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000177 (3).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000117 (5).png
# /kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/squamous.cell.carcinoma/000130 (4).png
# ...
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (154).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (103).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (274).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (89).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (279).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (80).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (518).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (459).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (361).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (324).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (69).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (328).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (220).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (497).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (428).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (130).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (507).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (292).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (115).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (82).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (164).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (134).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (436).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (104).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (355).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (215).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (551).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (435).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (384).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (58).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (309).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (3).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (437).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (251).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (180).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (179).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (353).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (298).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (185).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (214).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (177).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (275).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (168).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (267).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (8).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (41).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (378).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (374).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (29).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (393).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (405).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (246).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (414).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (363).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (368).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (238).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (277).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (245).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (122).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (516).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (210).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (421).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (559).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (121).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (332).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (257).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (94).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (222).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (357).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (52).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (236).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (406).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (50).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (227).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (250).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (165).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (422).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (74).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (57).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (546).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (102).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (478).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (467).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (147).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (268).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (91).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (213).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (70).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (417).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (432).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (429).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (108).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (544).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (318).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (20).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (542).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (338).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (484).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (326).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (106).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (525).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (556).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (228).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (387).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (131).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (263).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (63).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (182).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (319).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (382).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (310).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (410).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (291).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (283).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (472).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (512).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (200).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (204).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (53).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (506).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (99).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (62).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (219).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (118).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (120).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (360).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (273).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (534).jpg
# /kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (73).jpg

# %%
img = cv2.imread('/kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Bengin cases/Bengin case (10).jpg')
plt.title('Bengin Case')
plt.imshow(img, label = 'Bengin Case')

# %%
img = cv2.imread('/kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Malignant cases/Malignant case (10).jpg')
plt.title('Malignant Case')
plt.imshow(img)

# %%
img = cv2.imread('/kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset/Normal cases/Normal case (100).jpg')
plt.title('Normal Case')
plt.imshow(img)

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
dir = '/kaggle/input/the-iqothnccd-lung-cancer-dataset/The IQ-OTHNCCD lung cancer dataset'
img_width = 256
img_height = 256

# %%
# Second section of the path
categories = ['Bengin cases', 'Malignant cases', 'Normal cases']

# Now we get the images using complete path and store the images into img_data folder.
img_data = []
for cata in categories:
    folder = os.path.join(dir, cata)
    label = categories.index(cata)
    for img in os.listdir(folder):
        img_path = os.path.join(folder, img)

        try:
            # Attempt to read and resize the image
            img_array = cv2.imread(img_path)
            img_array = cv2.resize(img_array, (img_height, img_width))

            # Check if the image array is not empty
            if img_array is not None and not img_array.size == 0:
                img_data.append([img_array, label])

        except Exception as e:
            continue

# %%
random.shuffle(img_data)

# %%
x=[]
y=[]
for features,labels in img_data:
    x.append(features)
    y.append(labels)

#Convert X and Y list into array
X=np.array(x, dtype = float)
Y=np.array(y, dtype = float)

# %%
print(X[19])
# Out:
# [[[38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]
#   ...
#   [38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]]
#
#  [[38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]
#   ...
#   [38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]]
#
#  [[38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]
#   ...
#   [38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]]
#
#  ...
#
#  [[38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]
#   ...
#   [38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]]
#
#  [[38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]
#   ...
#   [38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]]
#
#  [[38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]
#   ...
#   [38. 38. 38.]
#   [38. 38. 38.]
#   [38. 38. 38.]]]

# %%
for i in range(len(X)):
    X[i] = X[i]/255.0

# %%
X.shape
# Out:
# (1097, 256, 256, 3)

# %%
x, x_test, y, y_test = train_test_split(X, Y, test_size = 0.2)

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 0.2)

# %%
model = Sequential()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense  # Example model
from tensorflow.keras.optimizers import Adam

# Create the ImageDataGenerator for real-time augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Compute any statistics required by the generator (e.g. for feature-wise normalization)
datagen.fit(x_train)

# Define model (example)
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=x_train.shape[1:]),
    MaxPooling2D(),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(len(np.unique(y_train)), activation='softmax')
])

# Compile model
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train using generator — this avoids memory overload
batch_size = 32
model.fit(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=20,
    validation_data=(x_val, y_val)  # Optional, if you have validation data
)
# Out:
# Epoch 1/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 699ms/step - accuracy: 0.4325 - loss: 18.3934 - val_accuracy: 0.5795 - val_loss: 2.6626
# Epoch 2/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6562 - loss: 2.7895 - val_accuracy: 0.5795 - val_loss: 2.3000
# Epoch 3/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 10s 460ms/step - accuracy: 0.5966 - loss: 1.3816 - val_accuracy: 0.6761 - val_loss: 0.8088
# Epoch 4/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5938 - loss: 0.8420 - val_accuracy: 0.6477 - val_loss: 0.8639
# Epoch 5/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 10s 451ms/step - accuracy: 0.5429 - loss: 0.9974 - val_accuracy: 0.6761 - val_loss: 0.8426
# Epoch 6/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6250 - loss: 0.8459 - val_accuracy: 0.6705 - val_loss: 0.8512
# Epoch 7/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 398ms/step - accuracy: 0.5890 - loss: 0.8504 - val_accuracy: 0.5341 - val_loss: 0.9644
# Epoch 8/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5938 - loss: 0.8420 - val_accuracy: 0.5341 - val_loss: 0.9871
# Epoch 9/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 10s 397ms/step - accuracy: 0.5804 - loss: 0.8937 - val_accuracy: 0.5966 - val_loss: 0.9095
# Epoch 10/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6562 - loss: 0.8918 - val_accuracy: 0.6364 - val_loss: 0.8727
# Epoch 11/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 448ms/step - accuracy: 0.6334 - loss: 0.8113 - val_accuracy: 0.6477 - val_loss: 0.8595
# Epoch 12/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6250 - loss: 0.7974 - val_accuracy: 0.5568 - val_loss: 1.0264
# Epoch 13/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 10s 454ms/step - accuracy: 0.6444 - loss: 0.8150 - val_accuracy: 0.6307 - val_loss: 0.8630
# Epoch 14/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6562 - loss: 0.8431 - val_accuracy: 0.7273 - val_loss: 0.7295
# Epoch 15/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 10s 447ms/step - accuracy: 0.6122 - loss: 0.8648 - val_accuracy: 0.5398 - val_loss: 0.9934
# Epoch 16/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5000 - loss: 0.8132 - val_accuracy: 0.5682 - val_loss: 0.9711
# Epoch 17/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 411ms/step - accuracy: 0.6158 - loss: 0.8128 - val_accuracy: 0.6875 - val_loss: 0.7592
# Epoch 18/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6875 - loss: 0.8317 - val_accuracy: 0.7045 - val_loss: 0.7571
# Epoch 19/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 9s 396ms/step - accuracy: 0.6057 - loss: 0.8591 - val_accuracy: 0.6193 - val_loss: 0.9235
# Epoch 20/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6562 - loss: 0.8079 - val_accuracy: 0.6591 - val_loss: 0.8735

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AvgPool2D, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam
import numpy as np

# Create the ImageDataGenerator for real-time augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Fit the generator to your training data
datagen.fit(x_train)

# Define the deep CNN model
model = Sequential()
model.add(Conv2D(128, (3, 3), padding='same', input_shape=(256, 256, 3), activation='relu'))
model.add(AvgPool2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))

model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))

model.add(MaxPooling2D(2, 2))
model.add(Flatten())
model.add(Dropout(0.2, seed=12))
model.add(Dense(3000, activation='relu'))
model.add(Dense(1500, activation='relu'))
model.add(Dense(3, activation='softmax'))  # Assumes 3-class classification

# Compile the model
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using the data generator
batch_size = 32
model.fit(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(x_train) // batch_size,
    epochs=20,
    validation_data=(x_val, y_val)
)
# Out:
# Epoch 1/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.4781 - loss: 1.5857 - val_accuracy: 0.5341 - val_loss: 0.9494
# Epoch 2/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 18s 33ms/step - accuracy: 0.4483 - loss: 0.9590 - val_accuracy: 0.5341 - val_loss: 0.9533
# Epoch 3/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 533ms/step - accuracy: 0.4951 - loss: 0.9450 - val_accuracy: 0.5341 - val_loss: 1.0000
# Epoch 4/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.4062 - loss: 1.0016 - val_accuracy: 0.5341 - val_loss: 1.0047
# Epoch 5/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 558ms/step - accuracy: 0.5418 - loss: 0.9660 - val_accuracy: 0.5000 - val_loss: 0.9161
# Epoch 6/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5625 - loss: 0.8277 - val_accuracy: 0.4659 - val_loss: 0.9402
# Epoch 7/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 550ms/step - accuracy: 0.5158 - loss: 0.9281 - val_accuracy: 0.5227 - val_loss: 0.9276
# Epoch 8/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.6250 - loss: 0.8958 - val_accuracy: 0.5852 - val_loss: 0.9084
# Epoch 9/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 510ms/step - accuracy: 0.5711 - loss: 0.8782 - val_accuracy: 0.5852 - val_loss: 0.8463
# Epoch 10/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6250 - loss: 0.8593 - val_accuracy: 0.5455 - val_loss: 0.8810
# Epoch 11/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 545ms/step - accuracy: 0.5678 - loss: 0.8783 - val_accuracy: 0.6307 - val_loss: 0.8502
# Epoch 12/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5312 - loss: 0.9004 - val_accuracy: 0.6364 - val_loss: 0.8669
# Epoch 13/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 555ms/step - accuracy: 0.5985 - loss: 0.8756 - val_accuracy: 0.6364 - val_loss: 0.8329
# Epoch 14/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7812 - loss: 0.7282 - val_accuracy: 0.6193 - val_loss: 0.8155
# Epoch 15/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 546ms/step - accuracy: 0.6182 - loss: 0.8323 - val_accuracy: 0.6875 - val_loss: 0.7568
# Epoch 16/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6562 - loss: 0.7983 - val_accuracy: 0.6875 - val_loss: 0.7511
# Epoch 17/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 547ms/step - accuracy: 0.5738 - loss: 0.8714 - val_accuracy: 0.6705 - val_loss: 0.7976
# Epoch 18/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.5862 - loss: 0.8102 - val_accuracy: 0.7330 - val_loss: 0.7917
# Epoch 19/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 12s 548ms/step - accuracy: 0.6285 - loss: 0.8051 - val_accuracy: 0.6534 - val_loss: 0.7765
# Epoch 20/20
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5000 - loss: 1.1683 - val_accuracy: 0.6648 - val_loss: 0.7517

# %%
model.add(Conv2D(128, (3, 3), padding = 'same', input_shape = X.shape[1: ], activation = 'relu'))
model.add(AvgPool2D(2,2))
model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))
model.add(Conv2D(128, (3, 3), activation = 'relu', padding = 'same'))

model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3, 3), activation = 'relu', padding = 'same'))
model.add(Conv2D(64, (3, 3), activation = 'relu', padding = 'same'))

model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dropout(0.2, seed = 12))
model.add(Dense(3000, activation = 'relu'))
model.add(Dense(1500, activation = 'relu'))
model.add(Dense(3, activation = 'softmax'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-6cee4a014907> in <cell line: 0>()
#       4
#       5
# ----> 6 model.add(Conv2D(128, (3, 3), padding='same', input_shape=(256, 256, 3), activation='relu'))
#       7 model.add(AvgPool2D(2, 2))
#       8 model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in add(self, layer, rebuild)
#     120         self._layers.append(layer)
#     121         if rebuild:
# --> 122             self._maybe_rebuild()
#     123         else:
#     124             self.built = False
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in _maybe_rebuild(self)
#     139         if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     140             input_shape = self._layers[0].batch_shape
# --> 141             self.build(input_shape)
#     142         elif hasattr(self._layers[0], "input_shape") and len(self._layers) > 1:
#     143             # We can build the Sequential model if the first layer has the
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in build_wrapper(*args, **kwargs)
#     226             with obj._open_name_scope():
#     227                 obj._path = current_path()
# --> 228                 original_build_method(*args, **kwargs)
#     229             # Record build config.
#     230             signature = inspect.signature(original_build_method)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in build(self, input_shape)
#     185         for layer in self._layers[1:]:
#     186             try:
# --> 187                 x = layer(x)
#     188             except NotImplementedError:
#     189                 # Can happen if shape inference is not implemented.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     200         if spec.min_ndim is not None:
#     201             if ndim is not None and ndim < spec.min_ndim:
# --> 202                 raise ValueError(
#     203                     f'Input {input_index} of layer "{layer_name}" '
#     204                     "is incompatible with the layer: "
#
# ValueError: Input 0 of layer "conv2d_1" is incompatible with the layer: expected min_ndim=4, found ndim=2. Full shape received: (None, 3)

# %%
# Save the model
model.save("lung_cancer_detection_model.h5")
from tensorflow.keras.models import load_model

# Load the saved model
loaded_model = load_model("lung_cancer_detection_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 256, 256, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 128, 128, 128)  │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 32, 32, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3000)           │    49,155,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1500)           │     4,501,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 3)              │         4,503 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,365,643 (207.39 MB)
#  Trainable params: 54,365,643 (207.39 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Import EarlyStopping callback
from tensorflow.keras.callbacks import EarlyStopping

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=3, restore_best_weights=True)

# %%
history = model.fit(x_train, y_train, validation_data = (x_val, y_val),epochs = 15)
# Out:
# Epoch 1/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 412ms/step - accuracy: 0.7791 - loss: 0.5587 - val_accuracy: 0.7898 - val_loss: 0.5179
# Epoch 2/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.8265 - loss: 0.4179 - val_accuracy: 0.8864 - val_loss: 0.3175
# Epoch 3/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.9214 - loss: 0.1963 - val_accuracy: 0.9091 - val_loss: 0.1907
# Epoch 4/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 268ms/step - accuracy: 0.9357 - loss: 0.1725 - val_accuracy: 0.9489 - val_loss: 0.1791
# Epoch 5/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 261ms/step - accuracy: 0.9366 - loss: 0.1417 - val_accuracy: 0.9716 - val_loss: 0.1120
# Epoch 6/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 262ms/step - accuracy: 0.9658 - loss: 0.0704 - val_accuracy: 0.9602 - val_loss: 0.2203
# Epoch 7/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 258ms/step - accuracy: 0.9683 - loss: 0.0749 - val_accuracy: 0.9489 - val_loss: 0.1615
# Epoch 8/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step - accuracy: 0.9889 - loss: 0.0376 - val_accuracy: 0.9659 - val_loss: 0.1081
# Epoch 9/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 265ms/step - accuracy: 0.9870 - loss: 0.0314 - val_accuracy: 0.9773 - val_loss: 0.0853
# Epoch 10/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - accuracy: 0.9967 - loss: 0.0192 - val_accuracy: 0.9716 - val_loss: 0.1152
# Epoch 11/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.9978 - loss: 0.0145 - val_accuracy: 0.9830 - val_loss: 0.1453
# Epoch 12/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 270ms/step - accuracy: 0.9961 - loss: 0.0095 - val_accuracy: 0.9886 - val_loss: 0.0607
# Epoch 13/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 262ms/step - accuracy: 0.9932 - loss: 0.0303 - val_accuracy: 0.9830 - val_loss: 0.0659
# Epoch 14/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - accuracy: 0.9972 - loss: 0.0076 - val_accuracy: 0.9830 - val_loss: 0.0671
# Epoch 15/15
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 266ms/step - accuracy: 0.9954 - loss: 0.0090 - val_accuracy: 0.9830 - val_loss: 0.0640

# %%
result = model.predict(x_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9673 - loss: 0.1329
# Test Loss: 0.10371826589107513
# Test Accuracy: 0.9727272987365723

# %%
plt.plot(history.history['accuracy'], label = 'Train accuracy')
plt.plot(history.history['val_accuracy'], label = 'val accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'best')

# %%
plt.plot(history.history['loss'], label = 'Train Loss')
plt.plot(history.history['val_loss'], label = 'Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = 'best')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the test image
image_path = '/kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/valid/Bengin cases/Bengin case (114).jpg'
img = cv2.imread(image_path)

img = cv2.resize(img, (img_height, img_width))

# Expand dimensions to create a batch of size 1
img = np.expand_dims(img, axis=0)

# Make prediction
prediction = model.predict(img)

# Interpret prediction
class_label = np.argmax(prediction)
confidence = prediction[0][class_label]

print("Predicted Class Label:", class_label)
print("Confidence:", confidence)

# Mapping class labels to categories
class_labels_to_categories = {0: 'Benign', 1: 'Malignant', 2: 'Normal'}

# Display the predicted category
predicted_category = class_labels_to_categories[class_label]
print("Predicted Category:", predicted_category)

img = cv2.imread(image_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title(predicted_category)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Predicted Class Label: 0
# Confidence: 1.0
# Predicted Category: Benign

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the test image
image_path = '/kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/test/MalignantCases/Malignant case (464).jpg'
img = cv2.imread(image_path)

img = cv2.resize(img, (img_height, img_width))

# Expand dimensions to create a batch of size 1
img = np.expand_dims(img, axis=0)

# Make prediction
prediction = model.predict(img)

# Interpret prediction
class_label = np.argmax(prediction)
confidence = prediction[0][class_label]

print("Predicted Class Label:", class_label)
print("Confidence:", confidence)

# Mapping class labels to categories
class_labels_to_categories = {0: 'Benign', 1: 'Malignant', 2: 'Normal'}

# Display the predicted category
predicted_category = class_labels_to_categories[class_label]
print("Predicted Category:", predicted_category)

img = cv2.imread(image_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title(predicted_category)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Class Label: 1
# Confidence: 1.0
# Predicted Category: Malignant

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the test image
image_path = '/kaggle/input/ct-scan-images-for-lung-cancer/LungcancerDataSet/Data/valid/normal/Normal case (345).jpg'
img = cv2.imread(image_path)


img = cv2.resize(img, (img_height, img_width))

# Expand dimensions to create a batch of size 1
img = np.expand_dims(img, axis=0)

# Make prediction
prediction = model.predict(img)

# Interpret prediction
class_label = np.argmax(prediction)
confidence = prediction[0][class_label]

print("Predicted Class Label:", class_label)
print("Confidence:", confidence)

# Mapping class labels to categories
class_labels_to_categories = {0: 'Benign', 1: 'Malignant', 2: 'Normal'}

# Display the predicted category
predicted_category = class_labels_to_categories[class_label]
print("Predicted Category:", predicted_category)

img = cv2.imread(image_path)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title(predicted_category)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Predicted Class Label: 2
# Confidence: 1.0
# Predicted Category: Normal

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Define true labels and predicted labels
true_labels = y_test
predicted_labels = np.argmax(result, axis=1)

# Calculate confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels_to_categories.values(),
            yticklabels=class_labels_to_categories.values())
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
